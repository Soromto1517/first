# %% [markdown]
# <a href="https://colab.research.google.com/github/Soromto1517/first/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
red_wine = pd.read_csv('red-wine.csv')
red_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
input_shape = [11]

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(units=1, input_shape=[11])
])

# %%
w, b = model.weights
print(w, b)
# Out:
# <tf.Variable 'dense_4/kernel:0' shape=(11, 1) dtype=float32, numpy=
# array([[ 0.31598324],
#        [-0.3292119 ],
#        [-0.00086027],
#        [-0.6480958 ],
#        [-0.5359882 ],
#        [ 0.45728987],
#        [-0.57210183],
#        [-0.35275343],
#        [ 0.36703616],
#        [ 0.37366074],
#        [ 0.14754313]], dtype=float32)> <tf.Variable 'dense_4/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>

# %%
X = red_wine.drop("quality", axis =1)
y = red_wine['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y_train
# Out:
# 1096    6
# 267     8
# 1340    6
# 58      5
# 531     5
#        ..
# 278     8
# 200     7
# 252     5
# 823     5
# 1462    6
# Name: quality, Length: 1279, dtype: int64

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(units=10, activation='relu', input_shape=[11]),
    layers.Dense(units=8, activation='relu'),
    layers.Dense(units = 1),
])

model.compile(
    optimizer='sgd',
    loss='mae',
    metrics=['mae']
)

fitting = model.fit(
    X_train, y_train,
    batch_size=256,
    epochs = 10,
)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 10.7820 - mae: 10.7820
# Epoch 2/10
# 5/5 [==============================] - 0s 4ms/step - loss: 2.7433 - mae: 2.7433
# Epoch 3/10
# 5/5 [==============================] - 0s 4ms/step - loss: 2.9289 - mae: 2.9289
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 3.0127 - mae: 3.0127
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 2.4957 - mae: 2.4957
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 1.9212 - mae: 1.9212
# Epoch 7/10
# 5/5 [==============================] - 0s 3ms/step - loss: 2.4432 - mae: 2.4432
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 1.9682 - mae: 1.9682
# Epoch 9/10
# 5/5 [==============================] - 0s 3ms/step - loss: 2.0399 - mae: 2.0399
# Epoch 10/10
# 5/5 [==============================] - 0s 3ms/step - loss: 1.8648 - mae: 1.8648

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 2.9721 - mae: 2.9721
# [2.972050428390503, 2.972050428390503]

# %%
history_df = pd.DataFrame(fitting.history)
history_df['loss'].plot();

# %%
y_preds = model.predict(X_test)
y_preds
# Out:
# 10/10 [==============================] - 0s 2ms/step
# array([[2.6138608 ],
#        [2.4100266 ],
#        [3.2199662 ],
#        [3.0168211 ],
#        [1.7156963 ],
#        [2.7252092 ],
#        [3.3943138 ],
#        [2.9271293 ],
#        [2.1339886 ],
#        [2.1294813 ],
#        [3.5422752 ],
#        [1.8280199 ],
#        [2.9290035 ],
#        [2.991087  ],
#        [3.63777   ],
#        [2.8302724 ],
#        [3.058535  ],
#        [1.9529326 ],
#        [3.177153  ],
#        [2.184405  ],
#        [2.9921453 ],
#        [2.1152728 ],
#        [2.1266718 ],
#        [2.2466881 ],
#        [2.2775128 ],
#        [1.9252381 ],
#        [3.8724904 ],
#        [3.7704237 ],
#        [2.766198  ],
#        [3.0885289 ],
#        [2.3306153 ],
#        [3.3506649 ],
#        [2.2640333 ],
#        [3.2959516 ],
#        [1.5078616 ],
#        [3.2021544 ],
#        [2.5376074 ],
#        [2.8812015 ],
#        [2.3217952 ],
#        [2.245242  ],
#        [2.001826  ],
# ...
